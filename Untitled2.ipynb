# %%
 t=0
f=0
count=int(input('한 학기 수업주차 입력:'))
for i in range(1,count+1):
    print('%d주차 강의에 출석하셨나요?'%i)
    a=int(input('출석은 1, 결석은 0: '))
    if(a==1):
        t+=1
    else:
        f+=1
if(f!=0):
    if((f/count)*100>=30): 
        print('수업일수 부족으로 학점 부여 불가!')
print('결석 횟수:%d\n출석 횟수:%d'%(f,t))
print('결석률은 %d%s입니다.'%((f/count)*100,'%'))
print('출석률은 %d%s입니다.'%((t/count)*100,'%'))
# Out:
# 한 학기 수업주차 입력:5
# 1주차 강의에 출석하셨나요?
# 출석은 1, 결석은 0: 1
# 2주차 강의에 출석하셨나요?
# 출석은 1, 결석은 0: 1
# 3주차 강의에 출석하셨나요?
# 출석은 1, 결석은 0: 1
# 4주차 강의에 출석하셨나요?
# 출석은 1, 결석은 0: 1
# 5주차 강의에 출석하셨나요?
# 출석은 1, 결석은 0: 0
# 결석 횟수:1
# 출석 횟수:4
# 결석률은 20%입니다.
# 출석률은 80%입니다.

# %% [markdown]
# #
