# %%
i=5
list1=[]
sum=0
for i in range(5):
    list1.append(int(input("점수를 입력하세요:")))
    sum

print(list1)
# Out:
# 점수를 입력하세요:95
# 점수를 입력하세요:30
# 점수를 입력하세요:67
# 점수를 입력하세요:96
# 점수를 입력하세요:45
# [95, 30, 67, 96, 45]
